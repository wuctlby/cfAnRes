# %%
import yaml 

with open("8_13.yml") as f:
    config = yaml.safe_load(f)

mc_runs = config["mc_runs"]
outputs = config["outputs"]
data_runs = config["data_runs"]

links = []
for run, output in zip(mc_runs, outputs):
    if run in data_runs:
        # print(f"Run {run} is linked to output {output}")
        links.append(output)
print(links)
# Out:
# Run 544124 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499409
# Run 544123 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499408
# Run 544122 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499407
# Run 544121 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499406
# Run 544116 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499405
# Run 544098 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499404
# Run 544095 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499403
# Run 544091 is linked to output /alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499402
# ['/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499409', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499408', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499407', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499406', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499405', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499404', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499403', '/alice/cern.ch/user/a/alihyperloop/jobs/0249/hy_2499402']
