# %% [markdown]
# ### list all files with `prefix` and/or `suffix` in a given directory

# %%
import os
def list_files_with_suffix(directory, prefix="", suffix=""):
    files = []
    for root, dirs, filenames in os.walk(directory):
        for filename in filenames:
            if filename.startswith(prefix) and prefix != "":
                pass
            elif prefix == "":
                pass
            else:
                continue
            if filename.endswith(suffix) and suffix != "":
                pass
            elif suffix == "":
                pass
            else:
                continue
            files.append(os.path.join(root, filename))
    return files

# %%
path = '''
/home/wuct/MetaData/MC/production/OO/test_apass2/data
'''
prefix = "AO2D"
suffix = ".root"

files = list_files_with_suffix(path.strip(), prefix=prefix, suffix=suffix)
for f in files:
    print(f)
# Out:
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320618/0004/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320618/0001/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320618/0002/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320618/0003/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0011/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0018/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0007/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0010/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0012/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0008/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0022/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0004/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0019/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0014/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0001/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0009/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0021/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0002/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0003/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0005/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0015/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0017/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0020/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0013/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0016/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320622/0006/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320621/0001/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320621/0002/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320621/0003/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0007/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0008/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0004/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0001/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0002/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0003/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0005/AO2D.root
# /home/wuct/MetaData/MC/production/OO/test_apass2/data/hy_4320619/0006/AO2D.root
