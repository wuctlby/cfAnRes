# %%
_SCRIPTS = {
    'all': 'a',
    'bulk': 'b'
}

from natsort import natsorted

print(natsorted(["a10_12", "a2_5", "a12_24", "a1_3"]))
# def _get_script_name(script_path):
#     if script_path not in _SCRIPTS.values():
#         raise ValueError(f"Script path '{script_path}' not found. Available keys: {list(_SCRIPTS.values())}")
#     return next(key for key, value in _SCRIPTS.items() if value == script_path)

# print(_get_script_name("a"))
# Out:
# ['a1', 'a2', 'a10']
